# %% [markdown]
# <br> 1. What do HTML and CSS stand for?
#
# * HTML - HyperText Markup Language
# * CSS - Cascade Style Sheets
#
#
# <br> 2. Would you rather use HTML or CSS, for putting paragraphs of text on a webpage?
# button?
#
# - HTML
#
# <br> 3. Would you rather use HTML or CSS, to change the font and background color of a button?
#
# - CSS
#
# <br> 5. What are the three parts of an HTML element? (image from paragraph)
#
# - Opening Tag
# - Content
# - Closing Tag
#
# <br> 4. What is an HTML tag?
#
# - An HTML tag determines the type of element it wraps and also contains the element's content.
#
# <br> 6. What is the purpose of the doctype declaration?
#
#     To determine the version of HTML that is used for the document being written.
#
# <br> 7. What is the HTML element?
#
#     An HTML element is a container for content.
#
# <br> 8. What is the purpose of the head element?
#
#     The head element is used to store metadata needed to render our website. In the head element we can include other elements such as meta charset, title, and many more.
#
# <br> 9. What is the purpose of the body element?
#
#     The body element is the root element that wraps the rest of the document.
#
# <br> 10. How do you create a paragraph in HTML?
#
#     To create a paragraph in HTML one uses the <p> PARAGRAPH </p> tag
#
# <br> 11. How do you create a heading in HTML?
#
#     To create a heading one can write between <h1-6> HEADING </h1-6> tags.
#
# <br> 12. How many different levels of headings are there and what is the difference between
# them?
#
#     There are 6 different levels of headings. In ascending order h1 is the largest and h6 is the smallest. They are all boldened and have varying degrees of importance.
#
# <br> 13. What element should you use to make text bold and important?
#
#     To make text bold one can you two different elements:
#
# - < b > - Only adds visual effect of bold text
# - < strong > - Adds visual effect of bold and is important.
#
# <br> 14. What element should you use to make text italicized to add emphasis to it?
#
#     To italicize text one can use to different elements:
#
# - < i > - Only italicizes text for visual effects
# - < em > - Emphasizes text and italicizes it
#
# <br> 15. What relationship does an element have with any nested elements within it?
#
#     It has a parent-child relationship with the elements within it.
#
# <br> 16. What relationship do two elements have if they are at the same level of nesting?
#
#     They share a sibling relationship.
#
# <br> 17. How do you create HTML comments?
#
#     To create comments in HTML, one must use the tags <!-- COMMENT -->
#
# <br> 18. What HTML tag is used to create an unordered list?
#
#     <ul> UNORDERED LIST </ul> creates an unordered list.
#
# <br> 19. What HTML tag is used to create an ordered list?
#
#     <ol> ORDERED LIST </ol> creates an ordered list.
#
# <br> 20. What HTML tag is used to create list items within both unordered and ordered lists?
#
#     <li> creates a list element within any type of list.
#
# <br> 21. What element is used to create a link?
#
#     <a href="HYPERLINK REFERENCE"> LINK </a> the anchor tag is used to create a link and the href attribute is the document/site we are linking to.
#
# <br> 22. What is an attribute?
#
#     It gives an element additional information and is placed in the opening tag.
#
# <br> 23. What attribute tells links where to go?
#
#     href=""
#
# <br> 24. What is the difference between an absolute and relative link?
#
#     Absolute links redirect to another website and need a protocol, domain, and path.
#
#     Relative links can only redirect to other pages that are relative to the page we are on. That is to say they link to pages on the same directory.
#
# <br> 25. Which element is used to display an image?
#
#     <img>
#
# <br> 26. What two attributes do images always need to have?
#
#     src=""
#
#     alt=""
#
# <br> 27. How do you access a parent directory in a file path?
#
#     ../
#
# <br> 28. What are the four main image formats that you can use for images on the web?
#
# - JPEG
# - PNG
# - GIF
# - SVG
